# %%
import pandas as pd
all_ages=pd.read_csv("all-ages2.csv")
recent_grads=pd.read_csv("recent-grads2.csv")
print(recent_grads.head(5))
all_ages.head(5)
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2405                       CHEMICAL ENGINEERING    Engineering
#
#    Total  Sample_size    Men  Women  ShareWomen  Employed  ...  Part_time  \
# 0   2339           36   2057    282    0.120564      1976  ...        270
# 1    756            7    679     77    0.101852       640  ...        170
# 2    856            3    725    131    0.153037       648  ...        133
# 3   1258           16   1123    135    0.107313       758  ...        150
# 4  32260          289  21239  11021    0.341631     25694  ...       5180
#
# ...

# %%
major_categories=all_ages["Major_category"].unique()
major_categories
# Out:
# array(['Agriculture & Natural Resources', 'Biology & Life Science',
#        'Engineering', 'Humanities & Liberal Arts',
#        'Communications & Journalism', 'Computers & Mathematics',
#        'Industrial Arts & Consumer Services', 'Education',
#        'Law & Public Policy', 'Interdisciplinary', 'Health',
#        'Social Science', 'Physical Sciences', ' Physical Sciences',
#        'Psychology & Social Work', '15726', 'Arts', 'Business'],
#       dtype=object)

# %%
""""def cat_count(row) :
    cat_counts={}
    for i in major_categories:
        if row["Major_category"]==i :
            cat_counts[i]+= row["Total"]
            print(cat_counts[i])
            #cat_counts[i] = cat_counts[i]+df["Total", i]
    return cat_counts
major_categories=all_ages["Major_category"].unique()
all_ages.apply(cat_count, axis=1) """
def cat_count(df):
    cat_counts={}
    for i in major_categories :
        mc_rows= df[df["Major_category"]==i]
        cat_counts[i]=mc_rows["Total"].sum()
    return cat_counts
major_categories=all_ages["Major_category"].unique()
cat_count(all_ages)
# Out:
#     Major_code                                  Major  \
# 0         1100                    GENERAL AGRICULTURE
# 1         1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2         1102                 AGRICULTURAL ECONOMICS
# 3         1103                        ANIMAL SCIENCES
# 4         1104                           FOOD SCIENCE
# 5         1105             PLANT SCIENCE AND AGRONOMY
# 6         1106                           SOIL SCIENCE
# 7         1199              MISCELLANEOUS AGRICULTURE
# 9         1302                               FORESTRY
# 10        1303           NATURAL RESOURCES MANAGEMENT
#
#                      Major_category   Total  Employed  \
# 0   Agriculture & Natural Resources  128148     90245
# 1   Agriculture & Natural Resources   95326     76865
# 2   Agriculture & Natural Resources   33955     26321
# 3   Agriculture & Natural Resources  103549     81177
# 4   Agriculture & Natural Resources   24280     17281
# ...

# %%
all_ages_cat_count=all_ages.pivot_table(index="Major_category", values="Total")
print(all_ages_cat_count)
# Out:
#                                              Total
# Major_category
#  Physical Sciences                    12166.000000
# 15726                                 12607.000000
# Agriculture & Natural Resources       63243.700000
# Arts                                 225733.125000
# Biology & Life Science                95584.714286
# Business                             758364.692308
# Communications & Journalism          450955.500000
# Computers & Mathematics              161943.454545
# Education                            293757.375000
# Engineering                          123310.793103
# Health                               245904.916667
# Humanities & Liberal Arts            249222.333333
# Industrial Arts & Consumer Services  169678.666667
# Interdisciplinary                     45199.000000
# Law & Public Policy                  180585.200000
# Physical Sciences                    112572.444444
# Psychology & Social Work             220808.666667
# ...

# %%
low_wage_proportion=recent_grads["Low_wage_jobs"].sum()/recent_grads["Total"].sum()
print(low_wage_proportion)
# Out:
# 0.09852546076122913

# %% [markdown]
# Utiliser une boucle for pour parcourir toutes les majors.
# Pour chaque Major et chaque DataFrame, filtrer seulement les lignes du DataFrame correspondant à cette major
# Comparer les valeurs pour la colonne "Unemployment_rate" pour voir lequel des 2 DataFrames possèdent la valeur la plus basse
# Incrémenter (cad ajouter 1) à la variable rg_lower_count si la valeur pour Unemployment_rate est plus petite dans le dataframe recent_grads que dans le dataframe all_ages
# Afficher le résultat rg_lower_count.

# %%
rg_lower_count = 0
for i in recent_grads["Major"]:
    rg_ur =recent_grads[recent_grads["Major"]==i]["Unemployment_rate"].values
    aa_ur=all_ages[all_ages["Major"]==i]["Unemployment_rate"].values
    if len(rg_ur)>0 and len(aa_ur)>0 :
        if rg_ur[0]<aa_ur[0]:
            rg_lower_count+= 1
    #if rg_major["Unemployment_rate"]< aa_major["Unemployment_rate"]:
        #rg_lower_count+= 1
rg_lower_count
# Out:
# 42
